# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiwari-249/Machine-Learning/blob/main/Underfitting_%26_Overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Code for Underfitting**

# %% [markdown]
# **Using very low model complexity: degree = 1**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate data
np.random.seed(0)
X = np.linspace(0, 1, 30).reshape(-1, 1)
y = np.sin(2*np.pi*X).ravel() + np.random.normal(0, 0.1, 30)

# Underfitting model (Degree 1)
poly = PolynomialFeatures(degree=1)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

y_pred = model.predict(X_poly)

# Plot
plt.scatter(X, y, label="Data")
plt.plot(X, y_pred, color='red', label="Underfit Model (Degree=1)")
plt.title("Underfitting Example")
plt.legend()
plt.show()

# %% [markdown]
# # **Code for Overfitting**

# %% [markdown]
# **Using very high model complexity: degree = 15**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate data
np.random.seed(0)
X = np.linspace(0, 1, 30).reshape(-1, 1)
y = np.sin(2*np.pi*X).ravel() + np.random.normal(0, 0.1, 30)

# Overfitting model (Degree 15)
poly = PolynomialFeatures(degree=15)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

y_pred = model.predict(X_poly)

# Plot
plt.scatter(X, y, label="Data")
plt.plot(X, y_pred, color='green', label="Overfit Model (Degree=15)")
plt.title("Overfitting Example")
plt.legend()
plt.show()

# %% [markdown]
# # **Underfitting vs Good Fit vs Overfitting**

# %% [markdown]
# **This compares degree = 1, degree = 5, degree = 15 models.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate data
np.random.seed(0)
X = np.linspace(0, 1, 30).reshape(-1, 1)
y = np.sin(2*np.pi*X).ravel() + np.random.normal(0, 0.1, 30)

degrees = [1, 5, 15]
colors = ["red", "blue", "green"]
labels = ["Underfit (Degree 1)", "Good Fit (Degree 5)", "Overfit (Degree 15)"]

plt.scatter(X, y, label="Data", color='black')

for d, c, label in zip(degrees, colors, labels):
    poly = PolynomialFeatures(degree=d)
    X_poly = poly.fit_transform(X)

    model = LinearRegression()
    model.fit(X_poly, y)

    y_pred = model.predict(X_poly)
    plt.plot(X, y_pred, color=c, label=label)

plt.title("Underfitting vs Good Fit vs Overfitting")
plt.legend()
plt.show()
