# %% [markdown]
# # **Operators + If-Else + Loops**

# %% [markdown]
# # **Operators in Python**
#
# ## **Operators**
# * Operators are special symbols in Python that perform operations on values or variables.
# * They tell Python what action to perform — such as adding, comparing, assigning, or checking conditions.
#
#
#
# 1.   Arithmetic Operators
# 2.   Logical Operators
# 3.   Bitwise Operators
# 4.   Assignment Operators
# 5.   Membership Operators

# %% [markdown]
# **1. Arithmetic Operators**
#
# Used for math operations.

# %%
# Addition
print(5 + 6)

# Subtraction
print(5 - 6)

# Multiplication
print(5 * 6)

# Division (floating result)
print(5 / 2)

# Floor division (integer result)
print(5 // 2)

# Modulus (remainder)
print(5 % 2)

# Exponent (power)
print(5 ** 2)
# Out:
# 11
# -1
# 30
# 2.5
# 2
# 1
# 25

# %% [markdown]
# **2. Relational / Comparison Operators**
#
# Used to compare values.

# %%
# Greater than
print(4 > 5)

# Less than
print(4 < 5)

# Greater than or equal to
print(4 >= 4)

# Less than or equal to
print(4 <= 4)

# Equal to → True
print(4 == 4)

# Not equal to
print(4 != 4)
# Out:
# False
# True
# True
# True
# True
# False

# %% [markdown]
# **3. Logical Operators**
#
# Used to combine conditions.

# %%
# AND returns the first false value
print(1 and 0)

# OR returns the first true value
print(1 or 0)

# NOT reverses the truth value
print(not 1)
# Out:
# 0
# 1
# False

# %% [markdown]
# **4. Bitwise Operators**
#
# Work on bits (0/1).

# %%
# Bitwise AND (compares bits of both numbers)
print(2 & 3)

# Bitwise OR (sets bit if any bit is 1)
print(2 | 3)

# Bitwise XOR (sets bit if bits are different)
print(2 ^ 3)

# Bitwise NOT (inverts all bits)
print(~3)

# Right shift (moves bits right, divides by 2)
print(4 >> 2)

# Left shift (moves bits left, multiplies by 2)
print(5 << 2)
# Out:
# 2
# 3
# 1
# -4
# 1
# 20

# %% [markdown]
# **5. Assignment Operators**
#
# Used to assign values.

# %%
# Assignment operator (=) assigns value
a = 2

# += adds value to existing variable (a = a + 2)
a += 2

# Print final value of a
print(a)
# Out:
# 4

# %% [markdown]
# **6. Membership Operators**
#
# Check presence in a sequence.
# *  in - checks if a value exists in a sequence
# *  not in - checks if a value does NOT exist in a sequence

# %%
# 'in' checks if a value exists in a sequence
print('D' in 'Delhi')

# 'not in' checks if a value does NOT exist in a sequence
print('D' not in 'Delhi')

# Check if 1 is present in the list
print(1 in [2, 3, 4, 5, 6])

# Check if 1 is NOT present in the list
print(1 not in [2, 3, 4, 5, 6])
# Out:
# True
# False
# False
# True

# %% [markdown]
# ### **Program- Find the sum of a 3 digit number entered by the user**

# %%
number = int(input('Enter a 3 digit number : '))

# 345 % 10 --> 5
a = number % 10

number = number // 10

# 34 % 10 --> 4
b = number % 10

number = number // 10

# 3 % 10 --> 3
c = number % 10

print('Sum = ',a+b+c)
# Out:
# Enter a 3 digit number : 345
# Sum =  12

# %% [markdown]
# # **If-else in Python**
#
# **if–else**
#
# if–else is used to make decisions in Python.
# The program checks a condition:
#
# *  If the condition is True → run the if block
#
# *  If the condition is False → run the else block
#
# **if–elif–else**
#
# When there are multiple conditions
#
# Use it when you need your program to choose between more than two possibilities.
#
# *  if → checks the first condition
#
# *  elif → checks other conditions if previous if/elif is False
#
# *  else → runs when all previous conditions are False
#
# **Nested if–else**
#
# A nested if–else is an if–else statement inside another if or else.
#
# It is used when a decision depends on another decision.
#
# *  Nested if–else allows complex decisions.
#
# *  Can have multiple levels of nesting, but avoid too many levels (hard to read).
#
# *  Indentation is very important; wrong indentation gives syntax errors.
#
# **Branching**
#
# Branching is when a program chooses between multiple paths of execution based on conditions.
#
# Think of it like a road with forks -> depending on the condition, the program takes a different path.
#
# *  Branching allows decision-making in multiple directions.
#
# *  Only one path executes per if–elif–else block.
#
# *  Nested branching helps handle complex decisions.
#
# *  Proper indentation is critical.

# %% [markdown]
# ### **Login program**

# %%
# email-> nitish.campusx@gmail.com
# password-> 1234

email = input('Enter email : ')
password = input('Enter password : ')

if email == 'nitish.campusx@gmail.com' and password == '1234':
  print('Welcome')
elif email == 'nitish.campusx@gmail.com' and password != '1234':
  # tell the user
  print('Incprrect password')
  password = input('Enter password Again : ')
  if password == '1234':
    print('Welcome Finally')
  else:
    print('Beta tumse na ho paayega')
else:
  print('Not Correct')
# Out:
# Enter email : nitish.campusx@gmail.com
# Enter password : 123
# Incprrect password
# Enter password Again : 1253
# Beta tumse na ho paayega

# %% [markdown]
# ### **if-else examples**
# 1. Find the min of 3 given numbers
# 2. Menu Driven Program

# %%
# 1. Find the min of 3 given numbers

a = int(input('Enter first num: '))
b = int(input('Enter second num: '))
c = int(input('Enter third num: '))

if a < b and a < c:
  print('Smallest is ',a)
elif b < c:
  print('Smallest is ',b)
else:
  print('Smallest is ',c)
# Out:
# Enter first num: 4
# Enter second num: 2
# Enter third num: 7
# Smallest is  2

# %%
# 2. Menu Driven Program

fnum = int(input('Enter first num: '))
snum = int(input('Enter second num: '))

op = input('Enter the operations: ')

if op == '+':
  print(fnum + snum)
elif op == '-':
  print(fnum - snum)
elif op == '*':
  print(fnum * snum)
else:
  print(fnum / snum)
# Out:
# Enter first num: 12
# Enter second num: 45
# Enter the operations: +
# 57

# %%
# Menu driven calculator

menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2. Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('Change pin')
elif menu == '2':
  print('Balance')
else:
  print('Exit')
# Out:
#
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# 2
# Balance

# %% [markdown]
# # **Modules in Python**
#
# A module is a file containing Python code (functions, variables, classes) that you can reuse in other programs using the import statement.
#
# Modules in Python follow the principle of “divide and reuse” – divide your code into reusable parts (modules) to keep programs organized, maintainable, and efficient.
#
#
# | Module   | Purpose                                       |
# | -------- | --------------------------------------------- |
# | math     | Math operations (sqrt, factorial, ceil/floor) |
# | keyword  | Check Python reserved keywords                |
# | random   | Generate random numbers or choices            |
# | datetime | Work with date & time                         |

# %% [markdown]
# ### **1. math module**
#
# Used for mathematical operations.

# %%
import math

# %%
math.factorial(5)
# Out:
# 120

# %%
math.floor(6.8)
# Out:
# 6

# %%
math.ceil(6.8)
# Out:
# 7

# %%
math.sqrt(196)
# Out:
# 14.0

# %% [markdown]
# ### **2. keyword module**
#
# Used to check reserved keywords in Python.

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### **3. random module**
#
# Used for generating random numbers or choosing random items.

# %%
import random

# %%
print(random.randint(1,100))
# Out:
# 18

# %% [markdown]
# ### **4. datetime module**
#
# Used for working with date and time.

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2025-12-12 17:04:46.004593

# %% [markdown]
# # **Loops in Python**
#
# A loop is used to execute a block of code repeatedly until a condition is met.
#
# Loops help in avoiding repetitive code and make programs shorter and more efficient.
#
#
# **Need for loops**
#
# To repeat tasks without writing code multiple times.
#
# To iterate over sequences like lists, strings, tuples, or ranges.
#
# To automate repetitive tasks like calculations, printing patterns, etc.
#
# **Real-Life Loop Examples (Flipkart, Amazon)**
#
# Displaying a list of products -> When you search “Mobile Phones” on Flipkart, it shows hundreds of products.
#
# Inside Flipkart’s backend, a loop is used.
#
# Real-life purpose:
#
# *  Show each product
#
# *  Load product image, price, ratings, details
#
# *  Loop repeats for every item in the database

# %% [markdown]
# ### **While Loop**
#
# Executes a block of code as long as a condition is True.
# Used when number of iterations is not known in advance.
#
# *  Condition is checked before each iteration
#
# *  Loop stops when condition becomes False
#
# *  Avoid infinite loops by changing variables inside the loop

# %%
# While loop example-> program to print the table

number = int(input('Enter the number: '))
i = 1
while i<11:
  print(number,'*',i,'=',number * i)
  i += 1
# Out:
# Enter the number: 10
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100

# %%
 # while loop with else

x = 1
while x < 3:
  print(x)
  x += 1
else:
  print('limit crossed')
# Out:
# 1
# 2
# limit crossed

# %%
# Guessing game

# generate a random integer between 1 and 100
import random
jackpot = random.randint(1,100)

guess = int(input('guess karo'))
counter = 1
while guess != jackpot:
  if guess < jackpot:
    print('galat!guess higher')
  else:
    print('galat!guess lower')

  guess = int(input('guess karo'))
  counter += 1

else:
  print('correct guess')
  print('attempts',counter)
# Out:
# guess karo22
# galat!guess lower
# guess karo15
# galat!guess lower
# guess karo6
# galat!guess lower
# guess karo3
# correct guess
# attempts 4

# %% [markdown]
# ### **For Loop**
#
# Executes a block of code for each item in a sequence (like list, tuple, string, or range).
#
# Used when number of iterations is known or finite.
#
# *  Iterates over every element in a sequence
#
# *  No need to manually change the variable
#
# *  range(start, stop, step) is commonly used for numbers

# %%
# For loop demo

for i in {1,2,3,4,5}:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Program - The current population of a town is 10000. The population of the town is increasing at the rate of 10% per year. You have to write a program to find out the population at the end of each of the last 10 years.

# %%
# Code Used in the session
curr_pop = 10000

for i in range(10,0,-1):
  print(i,curr_pop)
  curr_pop = curr_pop - 0.1*curr_pop
# Out:
# 10 10000
# 9 9000.0
# 8 8100.0
# 7 7290.0
# 6 6561.0
# 5 5904.9
# 4 5314.41
# 3 4782.969
# 2 4304.6721
# 1 3874.20489

# %%
# Correct Answer of above question:
curr_pop = 10000

for i in range(10,0,-1):
  print(i,curr_pop)
  curr_pop /= 1.1
# Out:
# 10 10000
# 9 9090.90909090909
# 8 8264.462809917353
# 7 7513.148009015775
# 6 6830.134553650703
# 5 6209.213230591548
# 4 5644.739300537771
# 3 5131.5811823070635
# 2 4665.07380209733
# 1 4240.976183724845

# %% [markdown]
# **Explanation :**
#
#
#
# To calculate the population for each year with a 10% increase, you can use a simpler equation based on the previous year's population. Let's assume the population of the previous year is represented by variable x.
#
# The equation can be written as:
#
# > Current Year Population = x * 1.1
#
# In this equation, the current year's population is equal to the previous year's population multiplied by 1.1, representing a 10% increase.
#
# To find the population of the previous year (x), we can rearrange the equation as follows:
#
# > x = Current Year Population / 1.1
#
# Using this simplified equation, if you have the current year's population (e.g., 10,000), you can divide it by 1.1 to calculate the population of the previous year.
#
# This equation allows you to calculate the population for each year, assuming you know the population of the current year and want to find the population of the previous year.
